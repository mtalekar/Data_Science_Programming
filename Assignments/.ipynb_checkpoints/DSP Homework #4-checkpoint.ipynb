# %% [markdown]
# ## Question 1

# %%
#Import Libraries
from __future__ import print_function
from matplotlib import pyplot as plt
from tensorflow import keras
from sklearn.metrics import confusion_matrix
from keras import backend as K
from keras.datasets import mnist
from keras.models import Sequential,model_from_json
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import RMSprop

# %%
# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# ...
# 11501568/11490434 [==============================] - 42s 4us/step

# %%
x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# 60000 train samples
# 10000 test samples

# %%
y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)

# %% [markdown]
# #### Model 1

# %%
model = Sequential()
model.add(Dense(500, activation='relu', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(300, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

# %%
batch_size = 128
num_classes = 10
epochs = 3

# %%
history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
# Out:
# Epoch 1/3
# 469/469 [==============================] - 6s 8ms/step - loss: 0.2558 - accuracy: 0.9215 - val_loss: 0.1074 - val_accuracy: 0.9665
# Epoch 2/3
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1056 - accuracy: 0.9685 - val_loss: 0.0983 - val_accuracy: 0.9689
# Epoch 3/3
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0767 - accuracy: 0.9767 - val_loss: 0.0656 - val_accuracy: 0.9797

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
print(history.history.keys())
# Out:
# Test loss: 0.06555292010307312
# Test accuracy: 0.9797000288963318
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')
plt.show()

# %% [markdown]
# #### Model 2

# %%
#model with new configuration
model = Sequential()
model.add(Dense(400, activation='relu', input_shape=(784,)))
model.add(Dropout(0.5))
model.add(Dense(200, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(100, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_3 (Dense)              (None, 400)               314000
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 400)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 200)               80200
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 100)               20100
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                1010
# ...

# %%
history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
# Out:
# Epoch 1/3
# 469/469 [==============================] - 5s 9ms/step - loss: 0.5786 - accuracy: 0.8223 - val_loss: 0.1785 - val_accuracy: 0.9473
# Epoch 2/3
# 469/469 [==============================] - 4s 9ms/step - loss: 0.2530 - accuracy: 0.9326 - val_loss: 0.1316 - val_accuracy: 0.9625
# Epoch 3/3
# 469/469 [==============================] - 4s 9ms/step - loss: 0.2030 - accuracy: 0.9483 - val_loss: 0.1163 - val_accuracy: 0.9689

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
print(history.history.keys())
# Out:
# Test loss: 0.11633440852165222
# Test accuracy: 0.9689000248908997
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')
plt.show()

# %% [markdown]
# #### Model 3

# %%
#model with new configuration
model = Sequential()
model.add(Dense(400, activation='relu', input_shape=(784,)))
model.add(Dropout(0.7))
model.add(Dense(300, activation='relu'))
model.add(Dropout(0.7))
model.add(Dense(250, activation='relu'))
model.add(Dropout(0.7))
model.add(Dense(10, activation='softmax'))

model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])
epochs = 7
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_7 (Dense)              (None, 400)               314000
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 400)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 300)               120300
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 250)               75250
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 250)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 10)                2510
# ...

# %%
history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))#,callbacks=1)#callback)
# Out:
# Epoch 1/7
# 469/469 [==============================] - 4s 9ms/step - loss: 0.9424 - accuracy: 0.6899 - val_loss: 0.2639 - val_accuracy: 0.9286
# Epoch 2/7
# 469/469 [==============================] - 4s 8ms/step - loss: 0.4239 - accuracy: 0.8899 - val_loss: 0.2049 - val_accuracy: 0.9457
# Epoch 3/7
# 469/469 [==============================] - 4s 8ms/step - loss: 0.3593 - accuracy: 0.9118 - val_loss: 0.1837 - val_accuracy: 0.9542
# Epoch 4/7
# 469/469 [==============================] - 4s 9ms/step - loss: 0.3414 - accuracy: 0.9218 - val_loss: 0.1769 - val_accuracy: 0.9574
# Epoch 5/7
# 469/469 [==============================] - 4s 9ms/step - loss: 0.3228 - accuracy: 0.9287 - val_loss: 0.1587 - val_accuracy: 0.9621
# Epoch 6/7
# 469/469 [==============================] - 4s 9ms/step - loss: 0.3157 - accuracy: 0.9307 - val_loss: 0.1533 - val_accuracy: 0.9640
# Epoch 7/7
# ...

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
print(history.history.keys())
# Out:
# Test loss: 0.1550958752632141
# Test accuracy: 0.9665000438690186
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')
plt.show()

# %% [markdown]
# The accuracy Dropped and the test loss increased so the model is overfitting the Data. we need add regularization parameters to account for it.

# %% [markdown]
# ## Question 2

# %%
#import libraries
from __future__ import print_function
from matplotlib import pyplot as plt
import keras
from sklearn.metrics import confusion_matrix
from keras import backend as K
from keras.datasets import mnist
from keras.models import Sequential,model_from_json
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adadelta

# %%
# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
print(x_train.shape)
# Out:
# (60000, 28, 28)

# %%
print(y_train[0])
# Out:
# 5

# %%
plt.imshow(x_train[0], cmap=plt.cm.binary)

# %%
x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# 60000 train samples
# 10000 test samples

# %%
# convert class vectors to binary class matrices
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %%
batch_size = 128
num_classes = 10
epochs = 3

# input image dimensions
img_rows, img_cols = 28, 28

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %% [markdown]
# #### Model 1

# %%
model = Sequential()
model.add(Conv2D(100, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))
model.add(Conv2D(200, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(50, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

# %%
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=RMSprop(),
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train,
          batch_size=128,
          epochs=3,
          verbose=1,
          validation_data=(x_test, y_test))
# Out:
# Epoch 1/3
# 469/469 [==============================] - 23s 45ms/step - loss: 0.3877 - accuracy: 0.8793 - val_loss: 0.0740 - val_accuracy: 0.9776
# Epoch 2/3
# 469/469 [==============================] - 21s 45ms/step - loss: 0.1584 - accuracy: 0.9544 - val_loss: 0.0461 - val_accuracy: 0.9855
# Epoch 3/3
# 469/469 [==============================] - 21s 44ms/step - loss: 0.1255 - accuracy: 0.9640 - val_loss: 0.0394 - val_accuracy: 0.9869

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.03939983248710632
# Test accuracy: 0.9869000315666199

# %% [markdown]
# #### Model 2

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

# %%
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=Adadelta(),
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=2,
          verbose=1,
          validation_data=(x_test, y_test))
# Out:
# Epoch 1/2
# 469/469 [==============================] - 11s 20ms/step - loss: 2.2823 - accuracy: 0.1509 - val_loss: 2.2524 - val_accuracy: 0.2962
# Epoch 2/2
# 469/469 [==============================] - 9s 19ms/step - loss: 2.2396 - accuracy: 0.2255 - val_loss: 2.1987 - val_accuracy: 0.4523

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 2.198726177215576
# Test accuracy: 0.4523000121116638

# %% [markdown]
# #### Model 3

# %%
model = Sequential()
model.add(Conv2D(150, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
model.add(Conv2D(60, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(24, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(num_classes, activation='softmax'))

# %%
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=RMSprop(),
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=1,
          verbose=1,
          validation_data=(x_test, y_test))
# Out:
# 469/469 [==============================] - 25s 53ms/step - loss: 0.4180 - accuracy: 0.8691 - val_loss: 0.0749 - val_accuracy: 0.9783

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.07491505146026611
# Test accuracy: 0.9783000349998474

# %% [markdown]
# ## Question 3

# %% [markdown]
# Based on Keras and CNN results, I can conclude that all the Keras models performed better relatively to CNN models showing better accuracy and less loss.

# %% [markdown]
# Other better architectures that can be used to built CNN models:
# 1)ResNet - This architecture of CNN built based on shortcut structure to reduce the error rate below 5% and also this performed better as it abled to solve the gradient vanishing problem.
# 2)SqueezeNet - In this architecture they used different size of filters with very less amount of memory.This resulted to acheive a better accuracy performance.
